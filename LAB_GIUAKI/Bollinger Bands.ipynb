# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. TẢI DỮ LIỆU
data = yf.download('AAPL', start='2015-01-01', end='2025-10-01', auto_adjust=False)

# Xử lý lỗi MultiIndex (do phiên bản yfinance mới thường trả về dạng cột lồng nhau)
if isinstance(data.columns, pd.MultiIndex):
    data.columns = data.columns.get_level_values(0)

data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Date
# 2025-09-24  252.065643  252.309998  255.740005  251.039993  255.220001
# 2025-09-25  256.621216  256.869995  257.170013  251.710007  253.210007
# 2025-09-26  255.212601  255.460007  257.600006  253.779999  254.100006
# 2025-09-29  254.183594  254.429993  255.000000  253.009995  254.559998
# 2025-09-30  254.383408  254.630005  255.919998  253.110001  254.860001
#
# Price         Volume
# Date
# 2025-09-24  42303700
# 2025-09-25  55202100
# 2025-09-26  46076300
# 2025-09-29  40127700
# 2025-09-30  37704300

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12,5))
plt.plot(data['Adj Close'], label='Adj Close')

plt.legend()
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("AAPL Adjust Close Price")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Xử lý missing value
data.ffill(inplace = True)
data.dropna(inplace = True)

# %%
# 2. TÍNH TOÁN BOLLINGER BANDS
window = 20
std_dev = 2

#  (SMA 20)
data['Middle Band'] = data['Adj Close'].rolling(window=window).mean()
# Độ lệch chuẩn
data['Std'] = data['Adj Close'].rolling(window=window).std()
# Dải trên và Dải dưới
data['Upper Band'] = data['Middle Band'] + (data['Std'] * std_dev)
data['Lower Band'] = data['Middle Band'] - (data['Std'] * std_dev)

# 3. XÂY DỰNG TÍN HIỆU GIAO DỊCH (Mean Reversion)
# Mua khi giá đóng cửa < Dải dưới
# Bán khi giá đóng cửa > Dải trên

data['Buy_Signal'] = np.where(data['Adj Close'] < data['Lower Band'], data['Adj Close'], np.nan)
data['Sell_Signal'] = np.where(data['Adj Close'] > data['Upper Band'], data['Adj Close'], np.nan)

# Lọc bớt tín hiệu để biểu đồ đỡ rối (chỉ lấy 1 năm cuối để xem cho rõ)
subset = data.loc['2023-01-01':]

# 4. VẼ BIỂU ĐỒ (VISUALIZATION)
plt.figure(figsize=(14, 7))

# Vẽ giá và các đường Bands
plt.plot(subset.index, subset['Adj Close'], label='Giá Adjust Close', color='black', alpha=0.6)
plt.plot(subset.index, subset['Upper Band'], label='Upper Band', color='green', alpha=0.3, linestyle='--')
plt.plot(subset.index, subset['Lower Band'], label='Lower Band', color='red', alpha=0.3, linestyle='--')
plt.plot(subset.index, subset['Middle Band'], label='SMA 20', color='orange', alpha=0.5)

# Tô màu nền giữa 2 dải (Mây Bollinger)
plt.fill_between(subset.index, subset['Upper Band'], subset['Lower Band'], color='gray', alpha=0.1)

# Vẽ mũi tên Mua/Bán
plt.scatter(subset.index, subset['Buy_Signal'], label='MUA (Chạm đáy)', marker='^', color='green', s=100, zorder=5)
plt.scatter(subset.index, subset['Sell_Signal'], label='BÁN (Chạm đỉnh)', marker='v', color='red', s=100, zorder=5)

plt.title('Chiến lược Bollinger Bands Đơn Giản - AAPL')
plt.xlabel('Thời gian')
plt.ylabel('Giá (USD)')
plt.legend(loc='best')
plt.grid(True, alpha=0.3)

plt.show()

# %%
# --- PHẦN 5: BACKTEST CHIẾN LƯỢC ---

# Khởi tạo biến cho vòng lặp mô phỏng
initial_capital = 100000  # Giả sử vốn ban đầu là 100,000 USD
cash = initial_capital
shares = 0
equity_curve = []  # Lưu giá trị tài sản theo thời gian

# Duyệt qua từng ngày trong dữ liệu (data)
for i in range(len(data)):
    # Lấy dữ liệu của ngày hiện tại
    current_price = data['Adj Close'].iloc[i]
    current_date = data.index[i]

    # Lấy ngưỡng Bands từ code cũ của bạn
    lower_band = data['Lower Band'].iloc[i]
    upper_band = data['Upper Band'].iloc[i]

    # 1. Tín hiệu MUA: Giá < Lower Band VÀ Đang cầm tiền (shares == 0)
    # Lưu ý: Ta kiểm tra điều kiện lại tại đây để đảm bảo không mua chồng chéo
    if current_price < lower_band and shares == 0:
        shares = cash / current_price # Mua hết tiền (All-in)
        cash = 0
        # print(f"MUA ngày {current_date.date()} giá {current_price:.2f}")

    # 2. Tín hiệu BÁN: Giá > Upper Band VÀ Đang cầm cổ phiếu (shares > 0)
    elif current_price > upper_band and shares > 0:
        cash = shares * current_price # Bán hết cổ phiếu
        shares = 0
        # print(f"BÁN ngày {current_date.date()} giá {current_price:.2f}")

    # 3. Tính tổng tài sản ngày hôm đó
    # Nếu đang cầm cổ phiếu: Tiền mặt + (Số cổ * Giá hiện tại)
    # Nếu đang cầm tiền: Tiền mặt
    current_equity = cash + (shares * current_price)
    equity_curve.append(current_equity)

# Lưu đường cong vốn vào DataFrame
data['Strategy_Equity'] = equity_curve

# --- TÍNH TOÁN HIỆU SUẤT ---
# Lợi nhuận chiến lược
strategy_return = (data['Strategy_Equity'].iloc[-1] - initial_capital) / initial_capital * 100

# Lợi nhuận nếu chỉ Mua và Nắm giữ (Buy & Hold) từ ngày đầu đến ngày cuối
buy_hold_return = (data['Adj Close'].iloc[-1] - data['Adj Close'].iloc[0]) / data['Adj Close'].iloc[0] * 100

print("-" * 30)
print(f"KẾT QUẢ BACKTEST (Vốn: ${initial_capital:,.0f})")
print(f"Lợi nhuận Chiến lược:   {strategy_return:.2f}%")
print(f"Lợi nhuận Buy & Hold:   {buy_hold_return:.2f}%")
print(f"Tài sản cuối cùng:      ${data['Strategy_Equity'].iloc[-1]:,.2f}")
print("-" * 30)

# --- VẼ BIỂU ĐỒ HIỆU SUẤT ---
plt.figure(figsize=(14, 6))

# Vẽ đường tài sản của chiến lược
plt.plot(data.index, data['Strategy_Equity'], label='Tài sản (Chiến lược BB)', color='blue', linewidth=2)

# Vẽ đường so sánh Buy & Hold (Quy đổi về cùng vốn ban đầu để dễ so sánh)
buy_hold_equity = (data['Adj Close'] / data['Adj Close'].iloc[0]) * initial_capital
plt.plot(data.index, buy_hold_equity, label='Tài sản (Buy & Hold)', color='gray', linestyle='--', alpha=0.7)

plt.title('So sánh Hiệu suất: Bollinger Bands vs. Buy & Hold')
plt.ylabel('Tổng tài sản (USD)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ------------------------------
# KẾT QUẢ BACKTEST (Vốn: $100,000)
# Lợi nhuận Chiến lược:   150.93%
# Lợi nhuận Buy & Hold:   949.54%
# Tài sản cuối cùng:      $250,934.92
# ------------------------------

# %% [markdown]
# Chiến lược: Trend Following
# - Mua vào: Khi giá đóng cửa cắt lên trên Đường giữa
# - Giữ lệnh: Kệ cho giá chạm Dải trên (Upper Band). Càng chạm dải trên càng tốt (thể hiện lực tăng mạnh). Không bán!
# - Bán ra (Thoát lệnh): Chỉ bán khi giá quay đầu cắt xuống dưới Đường giữa (Middle Band).
#
# So sánh nó với chiến lược "Buy & Hold" (Mua năm 2015 và giữ nguyên đến nay).

# %%
# BOLLINGER BANDS
window = 20
std_dev = 2

data['Middle Band'] = data['Adj Close'].rolling(window=window).mean()
data['Std'] = data['Adj Close'].rolling(window=window).std()
data['Upper Band'] = data['Middle Band'] + (data['Std'] * std_dev)
data['Lower Band'] = data['Middle Band'] - (data['Std'] * std_dev)

# 3. LOGIC BACKTEST (TREND FOLLOWING)

# Khởi tạo cột Signal bằng 0 hết
data['Signal'] = 0

# MUA: Vẫn giữ nguyên (Mua khi giá rẻ - chạm dải dưới)
# Mua khi giá đóng cửa > Middle Band (Bắt đầu xu hướng tăng)
data.loc[data['Adj Close'] > data['Middle Band'], 'Signal'] = 1

# BÁN: Chỉ bán khi giá gãy xuống dưới Lower Band (Hoặc đường nào đó thấp hơn)
# Để đơn giản, ta giữ lệnh luôn (Signal = 1) chừng nào giá chưa gãy đường MA20
# Nhưng để dùng lại các biến có sẵn, ta sẽ BÁN khi giá thủng Middle Band
data.loc[data['Adj Close'] < data['Middle Band'], 'Signal'] = 0

# --- QUAN TRỌNG: XỬ LÝ VỊ THẾ GIỮ LỆNH ---
# Logic trên là dạng từng điểm rời rạc. Để backtest đúng, ta cần vòng lặp hoặc logic ffill
# Cách đơn giản nhất cho người mới (Logic thô):
# Nếu Adj Close > Middle Band -> Giữ lệnh (1)
# Nếu Adj Close < Middle Band -> Cầm tiền (0)

data['Signal'] = np.where(data['Adj Close'] > data['Middle Band'], 1, 0)

# Dời tín hiệu đi 1 ngày (Mua bán vào giá mở cửa hôm sau)
data['Signal'] = data['Signal'].shift(1)
# 4. TÍNH TOÁN LỢI NHUẬN
# Tính % thay đổi giá hàng ngày
data['Market_Returns'] = data['Adj Close'].pct_change()

# Tính lợi nhuận chiến lược
# Dùng shift(1) để tránh "nhìn trước tương lai". Tín hiệu hôm nay dùng để giao dịch ngày mai.
data['Strategy_Returns'] = data['Market_Returns'] * data['Signal'].shift(1)

# Giả lập vốn 10,000 USD
initial_capital = 10000
data['Buy_Hold_Equity'] = initial_capital * (1 + data['Market_Returns']).cumprod()
data['Strategy_Equity'] = initial_capital * (1 + data['Strategy_Returns']).cumprod()

# 5. ĐÁNH GIÁ HIỆU QUẢ
total_return_str = (data['Strategy_Equity'].iloc[-1] / initial_capital - 1) * 100
total_return_bh = (data['Buy_Hold_Equity'].iloc[-1] / initial_capital - 1) * 100

print(f"--- KẾT QUẢ BACKTEST (2015 - Nay) ---")
print(f"Vốn ban đầu: ${initial_capital}")
print(f"1. Chiến lược Buy & Hold (Cứ mua để đó): ${data['Buy_Hold_Equity'].iloc[-1]:.2f} (Lãi {total_return_bh:.2f}%)")
print(f"2. Chiến lược Bollinger Bands:            ${data['Strategy_Equity'].iloc[-1]:.2f} (Lãi {total_return_str:.2f}%)")

# 6. VẼ BIỂU ĐỒ SO SÁNH
plt.figure(figsize=(12, 6))
plt.plot(data['Buy_Hold_Equity'], label='Buy & Hold (AAPL)', color='gray', alpha=0.5)
plt.plot(data['Strategy_Equity'], label='Bollinger Strategy', color='blue', linewidth=2)
plt.title('So sánh Lợi nhuận: Bollinger Bands vs Buy & Hold')
plt.xlabel('Năm')
plt.ylabel('Tài sản (USD)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# --- KẾT QUẢ BACKTEST (2015 - Nay) ---
# Vốn ban đầu: $10000
# 1. Chiến lược Buy & Hold (Cứ mua để đó): $104954.25 (Lãi 949.54%)
# 2. Chiến lược Bollinger Bands:            $83500.05 (Lãi 735.00%)

# %%
! git add .
! git commit -m "Update Bollinger Bands"
! git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	../__pycache__/
#
# nothing added to commit but untracked files present (use "git add" to track)
# To https://github.com/tamnguyen-2905/CF_Trang22110234_Thanh22110203_Tam22110193.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/tamnguyen-2905/CF_Trang22110234_Thanh22110203_Tam22110193.git'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
